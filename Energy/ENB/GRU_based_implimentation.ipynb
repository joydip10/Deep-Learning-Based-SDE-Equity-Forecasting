# %%
from yahooquery import Ticker
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import GRU, Dense, Activation
from tfkan.layers import DenseKAN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import os
# Out:
# 2025-11-28 09:24:07.717760: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-28 09:24:07.717810: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-28 09:24:07.719100: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-28 09:24:07.727171: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-28 09:24:08.717336: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/lib/cuda'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"   # ensures deterministic ops
os.environ["TF_CUDNN_DETERMINISTIC"] = "1" # ensures deterministic cuDNN kernels
from tensorflow.keras import backend as K
tf.config.experimental.enable_op_determinism()

# %%
symbol = 'ENB'
ticker = Ticker(symbol)
data = ticker.history(start='2000-01-01', end='2025-10-31', interval='1d')
prices = data.xs(symbol, level=0)['close']
prices.index = pd.to_datetime(prices.index)

# %%
train = prices.loc[:'2024-12']
test = prices.loc['2025-01':]

print(f"Training data: {len(train)} samples")
print(f"Test data: {len(test)} samples")
# Out:
# Training data: 6289 samples
# Test data: 208 samples

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# %%
def create_sequences(data, timestep=120):
    X, y = [], []
    for i in range(timestep, len(data)):
        X.append(data[i-timestep:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train, y_train_prices = create_sequences(train_scaled, 120)

# %%
train_last_days = train_scaled[-120:]
test_input_data = np.concatenate([train_last_days, test_scaled], axis=0)
X_test, y_test_prices = create_sequences(test_input_data, 120)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train_last = X_train[:, -1, 0]
y_train = np.column_stack([y_train_prices, y_train_last])

# %%
y_test_last = X_test[:, -1, 0]
y_test = np.column_stack([y_test_prices, y_test_last])

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (6169, 120, 1)
# y_train shape: (6169, 2)
# X_test shape: (208, 120, 1)
# y_test shape: (208, 2)

# %%
def custom_loss(y_true, y_pred):
    """
    Wiener/GBM process loss
    y_true[:, 0] = actual next price
    y_true[:, 1] = last price in window (S_t)
    y_pred[:, 0] = mu (drift)
    y_pred[:, 1] = log_sigma (log volatility)
    """
    mu = y_pred[:, 0]
    sigma = tf.exp(y_pred[:, 1])
    S_t = y_true[:, 1]
    Z = tf.random.normal(tf.shape(mu))
    S_pred = S_t * tf.exp(mu - 0.5 * sigma**2 + sigma * Z)
    return tf.reduce_mean(tf.square(S_pred - y_true[:, 0]))

# %%
model = tf.keras.Sequential([
    DenseKAN(units=16, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.GRU(64, activation='relu', return_sequences=False),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(2)  # [mu, log_sigma]
])
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-11-28 09:24:12.094869: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.140227: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.140470: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.141721: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.141943: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.142135: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.205434: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.205750: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.205883: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-11-28 09:24:12.205967: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 09:24:12.206096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6898 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=custom_loss,
    metrics=[tf.keras.metrics.MeanSquaredError()]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_kan (DenseKAN)        (None, 120, 16)           172
#
#  activation (Activation)     (None, 120, 16)           0
#
#  gru (GRU)                   (None, 64)                15744
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
# =================================================================
# Total params: 16046 (62.68 KB)
# Trainable params: 16034 (62.63 KB)
# Non-trainable params: 12 (48.00 Byte)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_kan_lstm_model.h5', monitor='val_loss', save_best_only=True
)

# %%
print("\nTraining model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=250,
    batch_size=32,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Training model...
# Epoch 1/250
# 2025-11-28 09:24:18.941523: I external/local_xla/xla/service/service.cc:168] XLA service 0x729010debe40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-28 09:24:18.941549: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2025-11-28 09:24:18.949357: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-28 09:24:18.970254: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764343459.089901  243905 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 193/193 [==============================] - 42s 188ms/step - loss: 0.0891 - mean_squared_error: 2.2775 - val_loss: 8.3484e-04 - val_mean_squared_error: 10.6112
# Epoch 2/250
# /home/cs/grad/dasj/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 193/193 [==============================] - 41s 210ms/step - loss: 0.0031 - mean_squared_error: 6.8453 - val_loss: 0.0013 - val_mean_squared_error: 9.8134
# Epoch 3/250
# 193/193 [==============================] - 50s 257ms/step - loss: 0.0011 - mean_squared_error: 9.6356 - val_loss: 2.7321e-04 - val_mean_squared_error: 13.6683
# Epoch 4/250
# 193/193 [==============================] - 50s 259ms/step - loss: 3.7458e-04 - mean_squared_error: 15.2325 - val_loss: 1.5783e-04 - val_mean_squared_error: 17.0848
# Epoch 5/250
# 193/193 [==============================] - 50s 258ms/step - loss: 1.6160e-04 - mean_squared_error: 20.1128 - val_loss: 1.2232e-04 - val_mean_squared_error: 25.3086
# Epoch 6/250
# 193/193 [==============================] - 50s 259ms/step - loss: 1.1560e-04 - mean_squared_error: 24.5280 - val_loss: 1.6493e-04 - val_mean_squared_error: 31.7382
# Epoch 7/250
# 193/193 [==============================] - 50s 259ms/step - loss: 1.0463e-04 - mean_squared_error: 28.9677 - val_loss: 1.0671e-04 - val_mean_squared_error: 32.3247
# Epoch 8/250
# 193/193 [==============================] - 50s 258ms/step - loss: 1.0331e-04 - mean_squared_error: 28.7091 - val_loss: 1.2410e-04 - val_mean_squared_error: 28.3439
# Epoch 9/250
# 193/193 [==============================] - 50s 258ms/step - loss: 9.6574e-05 - mean_squared_error: 29.5294 - val_loss: 1.2571e-04 - val_mean_squared_error: 31.3257
# Epoch 10/250
# 193/193 [==============================] - 50s 259ms/step - loss: 1.0044e-04 - mean_squared_error: 29.3484 - val_loss: 1.1543e-04 - val_mean_squared_error: 32.6923
# Epoch 11/250
# 193/193 [==============================] - 50s 259ms/step - loss: 1.0035e-04 - mean_squared_error: 28.7922 - val_loss: 1.0763e-04 - val_mean_squared_error: 34.2668
# Epoch 12/250
# 193/193 [==============================] - 50s 258ms/step - loss: 9.5242e-05 - mean_squared_error: 28.1309 - val_loss: 1.4622e-04 - val_mean_squared_error: 20.8963
# Epoch 13/250
# 193/193 [==============================] - 43s 223ms/step - loss: 9.4470e-05 - mean_squared_error: 29.2556 - val_loss: 1.2250e-04 - val_mean_squared_error: 27.5006
# Epoch 14/250
# 193/193 [==============================] - 43s 223ms/step - loss: 9.4141e-05 - mean_squared_error: 28.3220 - val_loss: 1.1670e-04 - val_mean_squared_error: 36.1033
# Epoch 15/250
# 193/193 [==============================] - 43s 223ms/step - loss: 9.2845e-05 - mean_squared_error: 31.7208 - val_loss: 1.1041e-04 - val_mean_squared_error: 31.3098
# Epoch 16/250
# 193/193 [==============================] - 37s 193ms/step - loss: 9.6464e-05 - mean_squared_error: 29.3452 - val_loss: 1.1336e-04 - val_mean_squared_error: 34.0289
# Epoch 17/250
# 193/193 [==============================] - 36s 188ms/step - loss: 9.3091e-05 - mean_squared_error: 29.2582 - val_loss: 1.2478e-04 - val_mean_squared_error: 35.2201
# Epoch 18/250
# 193/193 [==============================] - 30s 157ms/step - loss: 9.8327e-05 - mean_squared_error: 28.2398 - val_loss: 1.1500e-04 - val_mean_squared_error: 37.4801
# Epoch 19/250
# 193/193 [==============================] - 30s 156ms/step - loss: 9.2921e-05 - mean_squared_error: 29.6297 - val_loss: 1.1466e-04 - val_mean_squared_error: 33.9330
# Epoch 20/250
# 193/193 [==============================] - 30s 156ms/step - loss: 1.0743e-04 - mean_squared_error: 30.7534 - val_loss: 1.2809e-04 - val_mean_squared_error: 35.9586
# Epoch 21/250
# 193/193 [==============================] - 30s 156ms/step - loss: 9.3585e-05 - mean_squared_error: 32.7092 - val_loss: 1.0933e-04 - val_mean_squared_error: 30.3894
# Epoch 22/250
# 193/193 [==============================] - 30s 156ms/step - loss: 9.9300e-05 - mean_squared_error: 27.4981 - val_loss: 1.1710e-04 - val_mean_squared_error: 35.4612
# Epoch 23/250
# 193/193 [==============================] - 31s 158ms/step - loss: 9.5340e-05 - mean_squared_error: 29.8526 - val_loss: 1.0594e-04 - val_mean_squared_error: 29.3137
# Epoch 24/250
# 193/193 [==============================] - 30s 156ms/step - loss: 9.7175e-05 - mean_squared_error: 27.3548 - val_loss: 1.0640e-04 - val_mean_squared_error: 34.3643
# Epoch 25/250
# 193/193 [==============================] - 30s 157ms/step - loss: 9.6519e-05 - mean_squared_error: 30.8369 - val_loss: 1.0760e-04 - val_mean_squared_error: 33.8347
# Epoch 26/250
# 193/193 [==============================] - 30s 156ms/step - loss: 9.2585e-05 - mean_squared_error: 29.8840 - val_loss: 1.6958e-04 - val_mean_squared_error: 50.4755
# Epoch 27/250
# 193/193 [==============================] - 30s 156ms/step - loss: 1.0303e-04 - mean_squared_error: 29.7143 - val_loss: 2.3824e-04 - val_mean_squared_error: 31.4259
# Epoch 28/250
# 193/193 [==============================] - 26s 137ms/step - loss: 9.1708e-05 - mean_squared_error: 32.2111 - val_loss: 1.2042e-04 - val_mean_squared_error: 33.3750
# Epoch 29/250
# 193/193 [==============================] - 26s 133ms/step - loss: 9.8707e-05 - mean_squared_error: 33.5695 - val_loss: 1.0556e-04 - val_mean_squared_error: 29.8593
# Epoch 30/250
# 193/193 [==============================] - 26s 134ms/step - loss: 9.4392e-05 - mean_squared_error: 31.9819 - val_loss: 1.0642e-04 - val_mean_squared_error: 29.4816
# Epoch 31/250
# 193/193 [==============================] - 25s 131ms/step - loss: 1.0710e-04 - mean_squared_error: 29.3895 - val_loss: 1.0571e-04 - val_mean_squared_error: 34.0878
# Epoch 32/250
# 193/193 [==============================] - 19s 100ms/step - loss: 9.4558e-05 - mean_squared_error: 28.5921 - val_loss: 1.1192e-04 - val_mean_squared_error: 28.9238
# Epoch 33/250
# 193/193 [==============================] - 19s 98ms/step - loss: 9.4854e-05 - mean_squared_error: 26.8391 - val_loss: 1.2967e-04 - val_mean_squared_error: 26.5146
# Epoch 34/250
# 193/193 [==============================] - 19s 98ms/step - loss: 9.2765e-05 - mean_squared_error: 31.4487 - val_loss: 1.7737e-04 - val_mean_squared_error: 36.4697
# Epoch 35/250
# 193/193 [==============================] - 19s 98ms/step - loss: 9.3890e-05 - mean_squared_error: 30.3890 - val_loss: 1.0921e-04 - val_mean_squared_error: 33.3607
# Epoch 36/250
# 193/193 [==============================] - 19s 98ms/step - loss: 9.4227e-05 - mean_squared_error: 29.5272 - val_loss: 1.2294e-04 - val_mean_squared_error: 31.4940
# Epoch 37/250
# 193/193 [==============================] - 19s 98ms/step - loss: 9.3625e-05 - mean_squared_error: 30.4979 - val_loss: 1.3214e-04 - val_mean_squared_error: 29.2641
# Epoch 38/250
# 193/193 [==============================] - 19s 97ms/step - loss: 9.0245e-05 - mean_squared_error: 27.7539 - val_loss: 1.4990e-04 - val_mean_squared_error: 29.9841
# Epoch 39/250
# 193/193 [==============================] - 19s 97ms/step - loss: 9.5752e-05 - mean_squared_error: 27.8983 - val_loss: 1.5295e-04 - val_mean_squared_error: 35.7958
# Epoch 40/250
# 193/193 [==============================] - 16s 82ms/step - loss: 9.3917e-05 - mean_squared_error: 28.4503 - val_loss: 1.0759e-04 - val_mean_squared_error: 30.8119
# Epoch 41/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.1490e-05 - mean_squared_error: 29.0609 - val_loss: 1.1697e-04 - val_mean_squared_error: 33.7710
# Epoch 42/250
# 193/193 [==============================] - 15s 80ms/step - loss: 9.3051e-05 - mean_squared_error: 30.4159 - val_loss: 1.0659e-04 - val_mean_squared_error: 36.0373
# Epoch 43/250
# 193/193 [==============================] - 16s 82ms/step - loss: 9.4103e-05 - mean_squared_error: 28.4900 - val_loss: 1.9023e-04 - val_mean_squared_error: 38.7482
# Epoch 44/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.6283e-05 - mean_squared_error: 30.7249 - val_loss: 1.0945e-04 - val_mean_squared_error: 36.2794
# Epoch 45/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.3277e-05 - mean_squared_error: 33.3046 - val_loss: 1.1371e-04 - val_mean_squared_error: 24.7077
# Epoch 46/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.1423e-05 - mean_squared_error: 34.4567 - val_loss: 1.1239e-04 - val_mean_squared_error: 38.3881
# Epoch 47/250
# 193/193 [==============================] - 16s 82ms/step - loss: 9.0910e-05 - mean_squared_error: 33.0957 - val_loss: 1.1542e-04 - val_mean_squared_error: 36.1602
# Epoch 48/250
# 193/193 [==============================] - 15s 80ms/step - loss: 9.3179e-05 - mean_squared_error: 34.2924 - val_loss: 1.5739e-04 - val_mean_squared_error: 29.8680
# Epoch 49/250
# 193/193 [==============================] - 15s 80ms/step - loss: 9.2512e-05 - mean_squared_error: 36.5987 - val_loss: 1.0437e-04 - val_mean_squared_error: 33.0589
# Epoch 50/250
# 193/193 [==============================] - 16s 80ms/step - loss: 9.3582e-05 - mean_squared_error: 34.1983 - val_loss: 1.1553e-04 - val_mean_squared_error: 30.5278
# Epoch 51/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.0209e-05 - mean_squared_error: 36.1792 - val_loss: 1.1547e-04 - val_mean_squared_error: 36.4441
# Epoch 52/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.3315e-05 - mean_squared_error: 33.5344 - val_loss: 1.0851e-04 - val_mean_squared_error: 30.5916
# Epoch 53/250
# 193/193 [==============================] - 16s 81ms/step - loss: 8.9113e-05 - mean_squared_error: 39.7829 - val_loss: 1.2976e-04 - val_mean_squared_error: 50.0470
# Epoch 54/250
# 193/193 [==============================] - 16s 80ms/step - loss: 9.6531e-05 - mean_squared_error: 31.3442 - val_loss: 1.2458e-04 - val_mean_squared_error: 35.6409
# Epoch 55/250
# 193/193 [==============================] - 16s 82ms/step - loss: 8.9745e-05 - mean_squared_error: 32.8448 - val_loss: 1.1319e-04 - val_mean_squared_error: 37.3848
# Epoch 56/250
# 193/193 [==============================] - 16s 82ms/step - loss: 9.2399e-05 - mean_squared_error: 35.5214 - val_loss: 1.0982e-04 - val_mean_squared_error: 39.8841
# Epoch 57/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.2149e-05 - mean_squared_error: 34.4072 - val_loss: 1.0767e-04 - val_mean_squared_error: 32.6443
# Epoch 58/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.2690e-05 - mean_squared_error: 35.1603 - val_loss: 1.1114e-04 - val_mean_squared_error: 34.8803
# Epoch 59/250
# 193/193 [==============================] - 16s 83ms/step - loss: 9.0961e-05 - mean_squared_error: 37.0195 - val_loss: 1.0718e-04 - val_mean_squared_error: 37.8885
# Epoch 60/250
# 193/193 [==============================] - 15s 80ms/step - loss: 8.9176e-05 - mean_squared_error: 37.1746 - val_loss: 1.1780e-04 - val_mean_squared_error: 43.2999
# Epoch 61/250
# 193/193 [==============================] - 15s 79ms/step - loss: 9.0240e-05 - mean_squared_error: 34.4832 - val_loss: 1.2025e-04 - val_mean_squared_error: 37.9840
# Epoch 62/250
# 193/193 [==============================] - 16s 81ms/step - loss: 9.0080e-05 - mean_squared_error: 37.5280 - val_loss: 1.1498e-04 - val_mean_squared_error: 36.3791
# Epoch 63/250
# 193/193 [==============================] - 16s 82ms/step - loss: 9.0558e-05 - mean_squared_error: 34.5594 - val_loss: 1.4398e-04 - val_mean_squared_error: 26.8139
# Epoch 64/250
# 193/193 [==============================] - 15s 78ms/step - loss: 9.0528e-05 - mean_squared_error: 40.3715 - val_loss: 1.0566e-04 - val_mean_squared_error: 43.3151
# Epoch 65/250
# 193/193 [==============================] - 16s 80ms/step - loss: 8.9249e-05 - mean_squared_error: 35.0355 - val_loss: 1.1732e-04 - val_mean_squared_error: 35.2601
# Epoch 66/250
# 193/193 [==============================] - 16s 81ms/step - loss: 8.9296e-05 - mean_squared_error: 34.7051 - val_loss: 1.0635e-04 - val_mean_squared_error: 40.8553
# Epoch 67/250
# 193/193 [==============================] - 16s 82ms/step - loss: 8.8478e-05 - mean_squared_error: 36.3031 - val_loss: 1.0499e-04 - val_mean_squared_error: 31.4293
# Epoch 68/250
# 193/193 [==============================] - 15s 79ms/step - loss: 8.8347e-05 - mean_squared_error: 37.2009 - val_loss: 1.3303e-04 - val_mean_squared_error: 47.0745
# Epoch 69/250
# 193/193 [==============================] - 16s 81ms/step - loss: 8.8849e-05 - mean_squared_error: 37.3260 - val_loss: 1.0683e-04 - val_mean_squared_error: 43.5023

# %%
def predict_with_formula(model, X, num_simulations=100):
    predictions = model.predict(X, verbose=0)
    mu = predictions[:, 0]
    sigma = np.exp(predictions[:, 1])
    S_t = X[:, -1, 0]
    
    predicted_prices = []
    for i in range(len(X)):
        sim_prices = []
        for _ in range(num_simulations):
            Z = np.random.randn()
            S_next = S_t[i] * np.exp(mu[i] - 0.5 * sigma[i]**2 + sigma[i] * Z)
            sim_prices.append(S_next)
        predicted_prices.append(np.mean(sim_prices))
    
    return np.array(predicted_prices), mu, sigma

# %%
y_pred_scaled, mu_test, sigma_test = predict_with_formula(model, X_test, num_simulations=100)

# Inverse transform
y_pred_original = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
y_actual_original = scaler.inverse_transform(y_test_prices.reshape(-1, 1))

# %%
y_pred_original = y_pred_original[1:]
y_actual_original = pd.DataFrame(y_actual_original).shift(1).dropna().values.flatten()

# %%
mse = mean_squared_error(y_actual_original, y_pred_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_actual_original, y_pred_original)
r2 = r2_score(y_actual_original, y_pred_original)
mape = np.mean(np.abs((y_actual_original - y_pred_original) / y_actual_original)) * 100

print(f"\nTest Set Performance:")
print(f"  MSE: ${mse:.5f}")
print(f"  RMSE: ${rmse:.5f}")
print(f"  MAE: ${mae:.5f}")
print(f"  R² Score: {r2:.5f}")
print(f"  MAPE: {mape:.5f}%")
print(f"  Mean μ (drift): {np.mean(mu_test):.6f}")
print(f"  Mean σ (volatility): {np.mean(sigma_test):.6f}")
# Out:
# Test Set Performance:
#   MSE: $0.00001
#   RMSE: $0.00299
#   MAE: $0.00243
#   R² Score: 1.00000
#   MAPE: 5.30756%
#   Mean μ (drift): 0.000023
#   Mean σ (volatility): 0.000700

# %%
fig, axes = plt.subplots(4, 1, figsize=(10, 18))


# Plot 1: Actual vs Predicted
axes[0].plot(test.index[1:],y_actual_original,  label='Actual', marker='o', markersize=3, alpha=0.7)
axes[0].plot(test.index[1:],y_pred_original, label='Predicted', marker='x', markersize=3, alpha=0.7)
axes[0].set_xlabel('Test Sample')
axes[0].set_ylabel('Price ($)')
axes[0].set_title(f'KAN-GRU based {symbol} prediction using Wiener Process')
axes[0].legend()
axes[0].grid(True)

# Plot 2: Scatter Plot
axes[1].scatter(y_actual_original, y_pred_original, alpha=0.5)
axes[1].plot([y_actual_original.min(), y_actual_original.max()],
                [y_actual_original.min(), y_actual_original.max()], 'r--', lw=2)
axes[1].set_xlabel('Actual Price ($)')
axes[1].set_ylabel('Predicted Price ($)')
axes[1].set_title('Prediction Accuracy')
axes[1].grid(True)

# Plot 3: Drift (μ)
axes[2].plot(mu_test, color='blue', alpha=0.7)
axes[2].axhline(y=np.mean(mu_test), color='r', linestyle='--', label=f'Mean: {np.mean(mu_test):.6f}')
axes[2].set_xlabel('Test Sample')
axes[2].set_ylabel('μ (Drift)')
axes[2].set_title('Estimated Drift Parameter')
axes[2].legend()
axes[2].grid(True)

# Plot 4: Volatility (σ)
axes[3].plot(sigma_test, color='green', alpha=0.7)
axes[3].axhline(y=np.mean(sigma_test), color='r', linestyle='--', label=f'Mean: {np.mean(sigma_test):.6f}')
axes[3].set_xlabel('Test Sample')
axes[3].set_ylabel('σ (Volatility)')
axes[3].set_title('Estimated Volatility Parameter')
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()
