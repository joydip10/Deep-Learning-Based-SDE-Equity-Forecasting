# %%
from yahooquery import Ticker
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Activation
from tfkan.layers import DenseKAN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import os
# Out:
# 2025-11-28 12:29:51.521587: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-28 12:29:51.521616: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-28 12:29:51.522595: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-28 12:29:51.530329: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-28 12:29:52.527446: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/lib/cuda'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"   # ensures deterministic ops
os.environ["TF_CUDNN_DETERMINISTIC"] = "1" # ensures deterministic cuDNN kernels
from tensorflow.keras import backend as K
tf.config.experimental.enable_op_determinism()

# %%
symbol = 'DIS'
ticker = Ticker(symbol)
data = ticker.history(start='2000-01-01', end='2025-10-31', interval='1d')
prices = data.xs(symbol, level=0)['close']
prices.index = pd.to_datetime(prices.index)

# %%
train = prices.loc[:'2024-12']
test = prices.loc['2025-01':]

print(f"Training data: {len(train)} samples")
print(f"Test data: {len(test)} samples")
# Out:
# Training data: 6289 samples
# Test data: 208 samples

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# %%
def create_sequences(data, timestep=120):
    X, y = [], []
    for i in range(timestep, len(data)):
        X.append(data[i-timestep:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train, y_train_prices = create_sequences(train_scaled, 120)

# %%
train_last_days = train_scaled[-120:]
test_input_data = np.concatenate([train_last_days, test_scaled], axis=0)
X_test, y_test_prices = create_sequences(test_input_data, 120)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train_last = X_train[:, -1, 0]
y_train = np.column_stack([y_train_prices, y_train_last])

# %%
y_test_last = X_test[:, -1, 0]
y_test = np.column_stack([y_test_prices, y_test_last])

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (6169, 120, 1)
# y_train shape: (6169, 2)
# X_test shape: (208, 120, 1)
# y_test shape: (208, 2)

# %%
def custom_loss(y_true, y_pred):
    """
    Wiener/GBM process loss
    y_true[:, 0] = actual next price
    y_true[:, 1] = last price in window (S_t)
    y_pred[:, 0] = mu (drift)
    y_pred[:, 1] = log_sigma (log volatility)
    """
    mu = y_pred[:, 0]
    sigma = tf.exp(y_pred[:, 1])
    S_t = y_true[:, 1]
    Z = tf.random.normal(tf.shape(mu))
    S_pred = S_t * tf.exp(mu - 0.5 * sigma**2 + sigma * Z)
    return tf.reduce_mean(tf.square(S_pred - y_true[:, 0]))

# %%
model = tf.keras.Sequential([
    DenseKAN(units=32, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.LSTM(128, activation='elu', return_sequences=False),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(2)  # [mu, log_sigma]
])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-11-28 12:29:56.113549: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.154297: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.154586: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.155856: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.156074: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.156261: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.227809: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.228080: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.228198: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-11-28 12:29:56.228278: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:29:56.228407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5118 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=custom_loss,
    metrics=[tf.keras.metrics.MeanSquaredError()]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_kan (DenseKAN)        (None, 120, 32)           332
#
#  activation (Activation)     (None, 120, 32)           0
#
#  lstm (LSTM)                 (None, 128)               82432
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 83022 (324.30 KB)
# Trainable params: 83010 (324.26 KB)
# Non-trainable params: 12 (48.00 Byte)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_kan_lstm_model.h5', monitor='val_loss', save_best_only=True
)

# %%
print("\nTraining model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=250,
    batch_size=32,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Training model...
# Epoch 1/250
# 2025-11-28 12:30:02.944980: I external/local_xla/xla/service/service.cc:168] XLA service 0x749c893e2ea0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-28 12:30:02.945007: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2025-11-28 12:30:02.952850: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-28 12:30:02.973402: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764354603.092465  256769 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 193/193 [==============================] - 32s 137ms/step - loss: 0.0060 - mean_squared_error: 5.4192 - val_loss: 3.1184e-04 - val_mean_squared_error: 8.5521
# Epoch 2/250
#   1/193 [..............................] - ETA: 29s - loss: 8.8068e-04 - mean_squared_error: 7.9218
# /home/cs/grad/dasj/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 193/193 [==============================] - 30s 154ms/step - loss: 4.1530e-04 - mean_squared_error: 9.3835 - val_loss: 1.6656e-04 - val_mean_squared_error: 10.8222
# Epoch 3/250
# 193/193 [==============================] - 30s 155ms/step - loss: 1.8306e-04 - mean_squared_error: 13.0343 - val_loss: 1.6914e-04 - val_mean_squared_error: 13.6206
# Epoch 4/250
# 193/193 [==============================] - 30s 156ms/step - loss: 1.1186e-04 - mean_squared_error: 16.0195 - val_loss: 1.3631e-04 - val_mean_squared_error: 17.9901
# Epoch 5/250
# 193/193 [==============================] - 30s 157ms/step - loss: 1.0323e-04 - mean_squared_error: 17.7447 - val_loss: 1.1824e-04 - val_mean_squared_error: 19.1527
# Epoch 6/250
# 193/193 [==============================] - 30s 156ms/step - loss: 8.9487e-05 - mean_squared_error: 20.2210 - val_loss: 1.1841e-04 - val_mean_squared_error: 22.9043
# Epoch 7/250
# 193/193 [==============================] - 30s 156ms/step - loss: 7.4947e-05 - mean_squared_error: 22.0230 - val_loss: 1.0075e-04 - val_mean_squared_error: 27.7469
# Epoch 8/250
# 193/193 [==============================] - 30s 156ms/step - loss: 6.8619e-05 - mean_squared_error: 25.9023 - val_loss: 1.2871e-04 - val_mean_squared_error: 23.7122
# Epoch 9/250
# 193/193 [==============================] - 30s 156ms/step - loss: 7.1136e-05 - mean_squared_error: 25.3399 - val_loss: 9.9972e-05 - val_mean_squared_error: 24.4805
# Epoch 10/250
# 193/193 [==============================] - 30s 157ms/step - loss: 6.7253e-05 - mean_squared_error: 25.2584 - val_loss: 1.0228e-04 - val_mean_squared_error: 26.2326
# Epoch 11/250
# 193/193 [==============================] - 30s 156ms/step - loss: 6.8330e-05 - mean_squared_error: 25.6240 - val_loss: 1.0014e-04 - val_mean_squared_error: 28.5792
# Epoch 12/250
# 193/193 [==============================] - 30s 156ms/step - loss: 6.8025e-05 - mean_squared_error: 27.2980 - val_loss: 9.9193e-05 - val_mean_squared_error: 28.9594
# Epoch 13/250
# 193/193 [==============================] - 30s 154ms/step - loss: 6.6160e-05 - mean_squared_error: 31.4054 - val_loss: 1.4473e-04 - val_mean_squared_error: 32.0237
# Epoch 14/250
# 193/193 [==============================] - 27s 139ms/step - loss: 6.7003e-05 - mean_squared_error: 29.2847 - val_loss: 1.0318e-04 - val_mean_squared_error: 33.1685
# Epoch 15/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.7108e-05 - mean_squared_error: 28.1820 - val_loss: 1.1329e-04 - val_mean_squared_error: 36.0280
# Epoch 16/250
# 193/193 [==============================] - 27s 139ms/step - loss: 6.5538e-05 - mean_squared_error: 28.7826 - val_loss: 1.1943e-04 - val_mean_squared_error: 27.4288
# Epoch 17/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.6327e-05 - mean_squared_error: 30.4404 - val_loss: 9.8706e-05 - val_mean_squared_error: 28.9284
# Epoch 18/250
# 193/193 [==============================] - 27s 139ms/step - loss: 6.4051e-05 - mean_squared_error: 29.6130 - val_loss: 1.0024e-04 - val_mean_squared_error: 36.4283
# Epoch 19/250
# 193/193 [==============================] - 27s 139ms/step - loss: 6.1726e-05 - mean_squared_error: 30.4796 - val_loss: 1.6476e-04 - val_mean_squared_error: 32.8870
# Epoch 20/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.3079e-05 - mean_squared_error: 28.8804 - val_loss: 1.0381e-04 - val_mean_squared_error: 27.4103
# Epoch 21/250
# 193/193 [==============================] - 27s 141ms/step - loss: 5.9284e-05 - mean_squared_error: 29.6770 - val_loss: 1.0712e-04 - val_mean_squared_error: 30.4889
# Epoch 22/250
# 193/193 [==============================] - 27s 141ms/step - loss: 6.6671e-05 - mean_squared_error: 27.3106 - val_loss: 1.0234e-04 - val_mean_squared_error: 30.8584
# Epoch 23/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.2821e-05 - mean_squared_error: 32.6642 - val_loss: 9.8577e-05 - val_mean_squared_error: 41.4604
# Epoch 24/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.2125e-05 - mean_squared_error: 32.4106 - val_loss: 1.0180e-04 - val_mean_squared_error: 26.7887
# Epoch 25/250
# 193/193 [==============================] - 27s 138ms/step - loss: 5.9717e-05 - mean_squared_error: 32.8754 - val_loss: 1.0883e-04 - val_mean_squared_error: 38.2028
# Epoch 26/250
# 193/193 [==============================] - 27s 139ms/step - loss: 1.3801e-04 - mean_squared_error: 65.1238 - val_loss: 2.5988e-04 - val_mean_squared_error: 18.2054
# Epoch 27/250
# 193/193 [==============================] - 27s 138ms/step - loss: 8.1240e-05 - mean_squared_error: 20.9953 - val_loss: 9.7977e-05 - val_mean_squared_error: 26.8171
# Epoch 28/250
# 193/193 [==============================] - 27s 139ms/step - loss: 7.1857e-05 - mean_squared_error: 27.6025 - val_loss: 9.9157e-05 - val_mean_squared_error: 29.3444
# Epoch 29/250
# 193/193 [==============================] - 27s 138ms/step - loss: 7.1597e-05 - mean_squared_error: 26.3862 - val_loss: 9.8847e-05 - val_mean_squared_error: 29.7554
# Epoch 30/250
# 193/193 [==============================] - 28s 143ms/step - loss: 6.1552e-05 - mean_squared_error: 30.6062 - val_loss: 9.9550e-05 - val_mean_squared_error: 30.9209
# Epoch 31/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.2204e-05 - mean_squared_error: 31.8099 - val_loss: 1.0146e-04 - val_mean_squared_error: 32.4064
# Epoch 32/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.2364e-05 - mean_squared_error: 28.7067 - val_loss: 1.0092e-04 - val_mean_squared_error: 30.9401
# Epoch 33/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.2228e-05 - mean_squared_error: 30.5962 - val_loss: 1.0112e-04 - val_mean_squared_error: 31.1555
# Epoch 34/250
# 193/193 [==============================] - 26s 136ms/step - loss: 6.3780e-05 - mean_squared_error: 30.2377 - val_loss: 1.0778e-04 - val_mean_squared_error: 32.4234
# Epoch 35/250
# 193/193 [==============================] - 25s 132ms/step - loss: 6.1523e-05 - mean_squared_error: 31.5942 - val_loss: 1.0715e-04 - val_mean_squared_error: 33.1568
# Epoch 36/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.0741e-05 - mean_squared_error: 29.8623 - val_loss: 1.1069e-04 - val_mean_squared_error: 32.8724
# Epoch 37/250
# 193/193 [==============================] - 27s 140ms/step - loss: 5.9620e-05 - mean_squared_error: 30.1337 - val_loss: 9.8956e-05 - val_mean_squared_error: 29.4049
# Epoch 38/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.1770e-05 - mean_squared_error: 29.8470 - val_loss: 9.8585e-05 - val_mean_squared_error: 31.3876
# Epoch 39/250
# 193/193 [==============================] - 27s 141ms/step - loss: 6.1425e-05 - mean_squared_error: 30.0891 - val_loss: 1.1720e-04 - val_mean_squared_error: 30.4166
# Epoch 40/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.2118e-05 - mean_squared_error: 29.1547 - val_loss: 1.2643e-04 - val_mean_squared_error: 29.5696
# Epoch 41/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.0766e-05 - mean_squared_error: 28.4396 - val_loss: 1.0245e-04 - val_mean_squared_error: 31.1728
# Epoch 42/250
# 193/193 [==============================] - 27s 139ms/step - loss: 6.1177e-05 - mean_squared_error: 28.2928 - val_loss: 1.0087e-04 - val_mean_squared_error: 32.0620
# Epoch 43/250
# 193/193 [==============================] - 27s 139ms/step - loss: 5.9995e-05 - mean_squared_error: 31.2892 - val_loss: 1.0605e-04 - val_mean_squared_error: 38.0570
# Epoch 44/250
# 193/193 [==============================] - 27s 139ms/step - loss: 6.2222e-05 - mean_squared_error: 31.6688 - val_loss: 9.8221e-05 - val_mean_squared_error: 28.3529
# Epoch 45/250
# 193/193 [==============================] - 27s 140ms/step - loss: 5.8609e-05 - mean_squared_error: 31.1765 - val_loss: 1.1101e-04 - val_mean_squared_error: 31.0120
# Epoch 46/250
# 193/193 [==============================] - 27s 140ms/step - loss: 6.0552e-05 - mean_squared_error: 29.3728 - val_loss: 1.0983e-04 - val_mean_squared_error: 36.0320
# Epoch 47/250
# 193/193 [==============================] - 27s 138ms/step - loss: 6.3011e-05 - mean_squared_error: 27.9376 - val_loss: 9.8312e-05 - val_mean_squared_error: 36.0718

# %%
def predict_with_formula(model, X, num_simulations=100):
    predictions = model.predict(X, verbose=0)
    mu = predictions[:, 0]
    sigma = np.exp(predictions[:, 1])
    S_t = X[:, -1, 0]
    
    predicted_prices = []
    for i in range(len(X)):
        sim_prices = []
        for _ in range(num_simulations):
            Z = np.random.randn()
            S_next = S_t[i] * np.exp(mu[i] - 0.5 * sigma[i]**2 + sigma[i] * Z)
            sim_prices.append(S_next)
        predicted_prices.append(np.mean(sim_prices))
    
    return np.array(predicted_prices), mu, sigma

# %%
y_pred_scaled, mu_test, sigma_test = predict_with_formula(model, X_test, num_simulations=100)

# Inverse transform
y_pred_original = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
y_actual_original = scaler.inverse_transform(y_test_prices.reshape(-1, 1))

# %%
y_pred_original = y_pred_original[1:]
y_actual_original = pd.DataFrame(y_actual_original).shift(1).dropna().values.flatten()

# %%
mse = mean_squared_error(y_actual_original, y_pred_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_actual_original, y_pred_original)
r2 = r2_score(y_actual_original, y_pred_original)
mape = np.mean(np.abs((y_actual_original - y_pred_original) / y_actual_original)) * 100

print(f"\nTest Set Performance:")
print(f"  MSE: ${mse:.5f}")
print(f"  RMSE: ${rmse:.5f}")
print(f"  MAE: ${mae:.5f}")
print(f"  R² Score: {r2:.5f}")
print(f"  MAPE: {mape:.5f}%")
print(f"  Mean μ (drift): {np.mean(mu_test):.6f}")
print(f"  Mean σ (volatility): {np.mean(sigma_test):.6f}")
# Out:
# Test Set Performance:
#   MSE: $0.00283
#   RMSE: $0.05317
#   MAE: $0.04986
#   R² Score: 0.99997
#   MAPE: 9.89831%
#   Mean μ (drift): -0.000510
#   Mean σ (volatility): 0.001122

# %%
fig, axes = plt.subplots(4, 1, figsize=(10, 18))


# Plot 1: Actual vs Predicted
axes[0].plot(y_actual_original, label='Actual', marker='o', markersize=3, alpha=0.7)
axes[0].plot(y_pred_original, label='Predicted', marker='x', markersize=3, alpha=0.7)
axes[0].set_xlabel('Test Sample')
axes[0].set_ylabel('Price ($)')
axes[0].set_title(f'KAN-LSTM based {symbol} prediction using Wiener Process')
axes[0].legend()
axes[0].grid(True)

# Plot 2: Scatter Plot
axes[1].scatter(y_actual_original, y_pred_original, alpha=0.5)
axes[1].plot([y_actual_original.min(), y_actual_original.max()],
                [y_actual_original.min(), y_actual_original.max()], 'r--', lw=2)
axes[1].set_xlabel('Actual Price ($)')
axes[1].set_ylabel('Predicted Price ($)')
axes[1].set_title('Prediction Accuracy')
axes[1].grid(True)

# Plot 3: Drift (μ)
axes[2].plot(mu_test, color='blue', alpha=0.7)
axes[2].axhline(y=np.mean(mu_test), color='r', linestyle='--', label=f'Mean: {np.mean(mu_test):.6f}')
axes[2].set_xlabel('Test Sample')
axes[2].set_ylabel('μ (Drift)')
axes[2].set_title('Estimated Drift Parameter')
axes[2].legend()
axes[2].grid(True)

# Plot 4: Volatility (σ)
axes[3].plot(sigma_test, color='green', alpha=0.7)
axes[3].axhline(y=np.mean(sigma_test), color='r', linestyle='--', label=f'Mean: {np.mean(sigma_test):.6f}')
axes[3].set_xlabel('Test Sample')
axes[3].set_ylabel('σ (Volatility)')
axes[3].set_title('Estimated Volatility Parameter')
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()
