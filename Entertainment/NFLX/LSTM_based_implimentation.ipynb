# %%
from yahooquery import Ticker
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import LSTM, Dense, Activation
from tfkan.layers import DenseKAN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import os
# Out:
# 2025-11-28 12:30:16.588927: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-28 12:30:16.588962: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-28 12:30:16.590263: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-28 12:30:16.599414: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-28 12:30:17.696685: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
os.environ['XLA_FLAGS'] = '--xla_gpu_cuda_data_dir=/usr/lib/cuda'
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"   # ensures deterministic ops
os.environ["TF_CUDNN_DETERMINISTIC"] = "1" # ensures deterministic cuDNN kernels
from tensorflow.keras import backend as K
tf.config.experimental.enable_op_determinism()

# %%
symbol = 'NFLX'
ticker = Ticker(symbol)
data = ticker.history(start='2000-01-01', end='2025-10-31', interval='1d')
prices = data.xs(symbol, level=0)['close']
prices.index = pd.to_datetime(prices.index)

# %%
train = prices.loc[:'2024-12']
test = prices.loc['2025-01':]

print(f"Training data: {len(train)} samples")
print(f"Test data: {len(test)} samples")
# Out:
# Training data: 5691 samples
# Test data: 208 samples

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train.values.reshape(-1, 1))
test_scaled = scaler.transform(test.values.reshape(-1, 1))

# %%
def create_sequences(data, timestep=120):
    X, y = [], []
    for i in range(timestep, len(data)):
        X.append(data[i-timestep:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

# %%
X_train, y_train_prices = create_sequences(train_scaled, 120)

# %%
train_last_days = train_scaled[-120:]
test_input_data = np.concatenate([train_last_days, test_scaled], axis=0)
X_test, y_test_prices = create_sequences(test_input_data, 120)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
y_train_last = X_train[:, -1, 0]
y_train = np.column_stack([y_train_prices, y_train_last])

# %%
y_test_last = X_test[:, -1, 0]
y_test = np.column_stack([y_test_prices, y_test_last])

# %%
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (5571, 120, 1)
# y_train shape: (5571, 2)
# X_test shape: (208, 120, 1)
# y_test shape: (208, 2)

# %%
def custom_loss(y_true, y_pred):
    """
    Wiener/GBM process loss
    y_true[:, 0] = actual next price
    y_true[:, 1] = last price in window (S_t)
    y_pred[:, 0] = mu (drift)
    y_pred[:, 1] = log_sigma (log volatility)
    """
    mu = y_pred[:, 0]
    sigma = tf.exp(y_pred[:, 1])
    S_t = y_true[:, 1]
    Z = tf.random.normal(tf.shape(mu))
    S_pred = S_t * tf.exp(mu - 0.5 * sigma**2 + sigma * Z)
    return tf.reduce_mean(tf.square(S_pred - y_true[:, 0]))

# %%
model = tf.keras.Sequential([
    DenseKAN(units=32, input_shape=(X_train.shape[1], 1)),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.LSTM(128, activation='elu', return_sequences=False),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(2)  # [mu, log_sigma]
])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 2025-11-28 12:30:21.172186: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.216732: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.216996: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.219173: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.219490: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.219723: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.300274: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.300603: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.300747: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-11-28 12:30:21.300847: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-11-28 12:30:21.301003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4822 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080, pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=custom_loss,
    metrics=[tf.keras.metrics.MeanSquaredError()]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_kan (DenseKAN)        (None, 120, 32)           332
#
#  activation (Activation)     (None, 120, 32)           0
#
#  lstm (LSTM)                 (None, 128)               82432
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 2)                 258
#
# =================================================================
# Total params: 83022 (324.30 KB)
# Trainable params: 83010 (324.26 KB)
# Non-trainable params: 12 (48.00 Byte)
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, restore_best_weights=True
)
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'best_kan_lstm_model.h5', monitor='val_loss', save_best_only=True
)

# %%
print("\nTraining model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=250,
    batch_size=32,
    callbacks=[early_stopping, checkpoint],
    verbose=1
)
# Out:
# Training model...
# Epoch 1/250
# 2025-11-28 12:30:28.638370: I external/local_xla/xla/service/service.cc:168] XLA service 0x73fb452e8350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-11-28 12:30:28.638420: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080, Compute Capability 6.1
# 2025-11-28 12:30:28.646670: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-28 12:30:28.668523: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8902
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764354628.797256  257574 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 175/175 [==============================] - 34s 158ms/step - loss: 0.0062 - mean_squared_error: 3.6201 - val_loss: 8.9426e-04 - val_mean_squared_error: 19.2256
# Epoch 2/250
#   1/175 [..............................] - ETA: 27s - loss: 1.9917e-04 - mean_squared_error: 5.8435
# /home/cs/grad/dasj/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 175/175 [==============================] - 27s 157ms/step - loss: 4.1720e-04 - mean_squared_error: 6.5990 - val_loss: 0.0042 - val_mean_squared_error: 19.4352
# Epoch 3/250
# 175/175 [==============================] - 27s 156ms/step - loss: 2.0897e-04 - mean_squared_error: 8.7562 - val_loss: 0.0063 - val_mean_squared_error: 22.2297
# Epoch 4/250
# 175/175 [==============================] - 28s 157ms/step - loss: 1.4077e-04 - mean_squared_error: 10.5459 - val_loss: 0.0017 - val_mean_squared_error: 22.2864
# Epoch 5/250
# 175/175 [==============================] - 28s 157ms/step - loss: 9.2033e-05 - mean_squared_error: 12.9181 - val_loss: 9.0483e-04 - val_mean_squared_error: 24.6504
# Epoch 6/250
# 175/175 [==============================] - 27s 157ms/step - loss: 7.6961e-05 - mean_squared_error: 14.4036 - val_loss: 9.2044e-04 - val_mean_squared_error: 20.9054
# Epoch 7/250
# 175/175 [==============================] - 27s 156ms/step - loss: 7.9918e-05 - mean_squared_error: 16.0787 - val_loss: 0.0013 - val_mean_squared_error: 33.4614
# Epoch 8/250
# 175/175 [==============================] - 27s 157ms/step - loss: 7.8743e-05 - mean_squared_error: 16.0378 - val_loss: 6.1436e-04 - val_mean_squared_error: 26.9703
# Epoch 9/250
# 175/175 [==============================] - 27s 157ms/step - loss: 5.7530e-05 - mean_squared_error: 18.9156 - val_loss: 7.4015e-04 - val_mean_squared_error: 31.2631
# Epoch 10/250
# 175/175 [==============================] - 27s 157ms/step - loss: 6.2719e-05 - mean_squared_error: 19.8593 - val_loss: 6.9192e-04 - val_mean_squared_error: 47.2802
# Epoch 11/250
# 175/175 [==============================] - 28s 157ms/step - loss: 6.2706e-05 - mean_squared_error: 20.8668 - val_loss: 0.0025 - val_mean_squared_error: 29.1223
# Epoch 12/250
# 175/175 [==============================] - 27s 156ms/step - loss: 5.6802e-05 - mean_squared_error: 22.3726 - val_loss: 2.6051 - val_mean_squared_error: 19588.6582
# Epoch 13/250
# 175/175 [==============================] - 27s 156ms/step - loss: 6.1866e-05 - mean_squared_error: 21.0023 - val_loss: 6.6356e-04 - val_mean_squared_error: 39.5511
# Epoch 14/250
# 175/175 [==============================] - 25s 140ms/step - loss: 5.0435e-05 - mean_squared_error: 22.5765 - val_loss: 6.0422e-04 - val_mean_squared_error: 39.0992
# Epoch 15/250
# 175/175 [==============================] - 24s 138ms/step - loss: 5.4269e-05 - mean_squared_error: 23.6486 - val_loss: 6.0660e-04 - val_mean_squared_error: 33.5956
# Epoch 16/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.2866e-05 - mean_squared_error: 25.9734 - val_loss: 5.9474e-04 - val_mean_squared_error: 33.3487
# Epoch 17/250
# 175/175 [==============================] - 24s 138ms/step - loss: 5.1965e-05 - mean_squared_error: 22.1330 - val_loss: 7.0991e-04 - val_mean_squared_error: 38.5926
# Epoch 18/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.7324e-05 - mean_squared_error: 25.4797 - val_loss: 5.9873e-04 - val_mean_squared_error: 36.1041
# Epoch 19/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.2319e-05 - mean_squared_error: 22.7998 - val_loss: 5.9800e-04 - val_mean_squared_error: 35.6514
# Epoch 20/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.1686e-05 - mean_squared_error: 23.9657 - val_loss: 7.4980e-04 - val_mean_squared_error: 32.6847
# Epoch 21/250
# 175/175 [==============================] - 24s 140ms/step - loss: 5.3013e-05 - mean_squared_error: 25.4000 - val_loss: 6.5042e-04 - val_mean_squared_error: 37.0290
# Epoch 22/250
# 175/175 [==============================] - 25s 141ms/step - loss: 5.9538e-05 - mean_squared_error: 23.4388 - val_loss: 9.3748e-04 - val_mean_squared_error: 35.0075
# Epoch 23/250
# 175/175 [==============================] - 24s 140ms/step - loss: 5.6870e-05 - mean_squared_error: 23.7099 - val_loss: 6.1899e-04 - val_mean_squared_error: 34.9160
# Epoch 24/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.0643e-05 - mean_squared_error: 24.6536 - val_loss: 6.0307e-04 - val_mean_squared_error: 31.1394
# Epoch 25/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.6654e-05 - mean_squared_error: 22.9892 - val_loss: 6.2277e-04 - val_mean_squared_error: 35.0371
# Epoch 26/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.1270e-05 - mean_squared_error: 25.5090 - val_loss: 5.9565e-04 - val_mean_squared_error: 42.7732
# Epoch 27/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.2163e-05 - mean_squared_error: 25.2072 - val_loss: 6.7740e-04 - val_mean_squared_error: 37.5563
# Epoch 28/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.4314e-05 - mean_squared_error: 23.2097 - val_loss: 6.7618e-04 - val_mean_squared_error: 36.8469
# Epoch 29/250
# 175/175 [==============================] - 24s 138ms/step - loss: 5.1446e-05 - mean_squared_error: 25.2924 - val_loss: 0.0012 - val_mean_squared_error: 38.6749
# Epoch 30/250
# 175/175 [==============================] - 24s 140ms/step - loss: 5.1048e-05 - mean_squared_error: 25.5804 - val_loss: 8.6276e-04 - val_mean_squared_error: 35.5136
# Epoch 31/250
# 175/175 [==============================] - 24s 139ms/step - loss: 5.1065e-05 - mean_squared_error: 26.5855 - val_loss: 6.5600e-04 - val_mean_squared_error: 34.6936
# Epoch 32/250
# 175/175 [==============================] - 25s 141ms/step - loss: 5.3839e-05 - mean_squared_error: 25.7587 - val_loss: 6.5228e-04 - val_mean_squared_error: 40.4227
# Epoch 33/250
# 175/175 [==============================] - 24s 139ms/step - loss: 4.8821e-05 - mean_squared_error: 25.1895 - val_loss: 6.5873e-04 - val_mean_squared_error: 42.0595
# Epoch 34/250
# 175/175 [==============================] - 25s 141ms/step - loss: 5.2654e-05 - mean_squared_error: 24.4831 - val_loss: 6.0316e-04 - val_mean_squared_error: 38.9083
# Epoch 35/250
# 175/175 [==============================] - 24s 140ms/step - loss: 4.9852e-05 - mean_squared_error: 27.7306 - val_loss: 0.0011 - val_mean_squared_error: 35.2033
# Epoch 36/250
# 175/175 [==============================] - 24s 140ms/step - loss: 5.3593e-05 - mean_squared_error: 27.0268 - val_loss: 6.1063e-04 - val_mean_squared_error: 40.6070

# %%
def predict_with_formula(model, X, num_simulations=100):
    predictions = model.predict(X, verbose=0)
    mu = predictions[:, 0]
    sigma = np.exp(predictions[:, 1])
    S_t = X[:, -1, 0]
    
    predicted_prices = []
    for i in range(len(X)):
        sim_prices = []
        for _ in range(num_simulations):
            Z = np.random.randn()
            S_next = S_t[i] * np.exp(mu[i] - 0.5 * sigma[i]**2 + sigma[i] * Z)
            sim_prices.append(S_next)
        predicted_prices.append(np.mean(sim_prices))
    
    return np.array(predicted_prices), mu, sigma

# %%
y_pred_scaled, mu_test, sigma_test = predict_with_formula(model, X_test, num_simulations=100)

# Inverse transform
y_pred_original = scaler.inverse_transform(y_pred_scaled.reshape(-1, 1))
y_actual_original = scaler.inverse_transform(y_test_prices.reshape(-1, 1))

# %%
y_pred_original = y_pred_original[1:]
y_actual_original = pd.DataFrame(y_actual_original).shift(1).dropna().values.flatten()

# %%
mse = mean_squared_error(y_actual_original, y_pred_original)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_actual_original, y_pred_original)
r2 = r2_score(y_actual_original, y_pred_original)
mape = np.mean(np.abs((y_actual_original - y_pred_original) / y_actual_original)) * 100

print(f"\nTest Set Performance:")
print(f"  MSE: ${mse:.5f}")
print(f"  RMSE: ${rmse:.5f}")
print(f"  MAE: ${mae:.5f}")
print(f"  R² Score: {r2:.5f}")
print(f"  MAPE: {mape:.5f}%")
print(f"  Mean μ (drift): {np.mean(mu_test):.6f}")
print(f"  Mean σ (volatility): {np.mean(sigma_test):.6f}")
# Out:
# Test Set Performance:
#   MSE: $0.10409
#   RMSE: $0.32262
#   MAE: $0.32094
#   R² Score: 0.99942
#   MAPE: 14.05240%
#   Mean μ (drift): 0.002965
#   Mean σ (volatility): 0.001035

# %%
fig, axes = plt.subplots(4, 1, figsize=(10, 18))


# Plot 1: Actual vs Predicted
axes[0].plot(y_actual_original, label='Actual', marker='o', markersize=3, alpha=0.7)
axes[0].plot(y_pred_original, label='Predicted', marker='x', markersize=3, alpha=0.7)
axes[0].set_xlabel('Test Sample')
axes[0].set_ylabel('Price ($)')
axes[0].set_title(f'KAN-LSTM based {symbol} prediction using Wiener Process')
axes[0].legend()
axes[0].grid(True)

# Plot 2: Scatter Plot
axes[1].scatter(y_actual_original, y_pred_original, alpha=0.5)
axes[1].plot([y_actual_original.min(), y_actual_original.max()],
                [y_actual_original.min(), y_actual_original.max()], 'r--', lw=2)
axes[1].set_xlabel('Actual Price ($)')
axes[1].set_ylabel('Predicted Price ($)')
axes[1].set_title('Prediction Accuracy')
axes[1].grid(True)

# Plot 3: Drift (μ)
axes[2].plot(mu_test, color='blue', alpha=0.7)
axes[2].axhline(y=np.mean(mu_test), color='r', linestyle='--', label=f'Mean: {np.mean(mu_test):.6f}')
axes[2].set_xlabel('Test Sample')
axes[2].set_ylabel('μ (Drift)')
axes[2].set_title('Estimated Drift Parameter')
axes[2].legend()
axes[2].grid(True)

# Plot 4: Volatility (σ)
axes[3].plot(sigma_test, color='green', alpha=0.7)
axes[3].axhline(y=np.mean(sigma_test), color='r', linestyle='--', label=f'Mean: {np.mean(sigma_test):.6f}')
axes[3].set_xlabel('Test Sample')
axes[3].set_ylabel('σ (Volatility)')
axes[3].set_title('Estimated Volatility Parameter')
axes[3].legend()
axes[3].grid(True)

plt.tight_layout()
plt.show()
